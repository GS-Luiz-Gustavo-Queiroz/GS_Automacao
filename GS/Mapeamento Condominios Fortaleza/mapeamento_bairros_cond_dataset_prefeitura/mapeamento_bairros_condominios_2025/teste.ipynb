# %%
import pandas as pd
import numpy as np

# %%
condominios = pd.read_csv("condominios_total.csv", dtype=str, encoding='latin1')
condominios = condominios[:5]
condominios
condominios = condominios.drop(['razao_social'], axis=1)

# %%
condominios
# Out:
#                cnpj matriz_filial                           nome_fantasia  \
# 0  22157373/0001-03             1                                     NaN
# 1  08448393/0001-02             1                                     NaN
# 2  26073984/0001-24             1                            AR1 SOLUCOES
# 3  26130593/0001-02             1  CONDOMINIO RESIDENCIAL MONTEIRO LOBATO
# 4  26186449/0001-80             1     CONDOMINIO RESIDENCIAL CASTRO ALVES
#
#   sit_cadast data_sit_cadast motivo_sit_cadast nome_cidade_exterior pais  \
# 0         02      04/09/2014                00                  NaN  NaN
# 1         02      08/11/2006                00                  NaN  NaN
# 2         04      20/03/2019                63                  NaN  NaN
# 3         02      10/06/2016                00                  NaN  NaN
# 4         02      23/06/2016                00                  NaN  NaN
#
#   data_inicio cnae_principal  ...       cep  uf municipio ddd1 telefone1 ddd2  \
# ...

# %%
nomes_colunas = ["cnpj", "razao_social", "nat_jurid", "qual_resp", "capit_soc", "porte", "ente_fed"]
empresas = pd.read_csv("Empresas1.csv", sep=";", dtype=str, encoding='latin1', names=nomes_colunas)
empresas = empresas[:3]
empresas
# Out:
#        cnpj                                       razao_social nat_jurid  \
# 0  00000000                                 BANCO DO BRASIL SA      2038
# 1  00000001  ASSOCIACAO DE AMIGOS DE BAIRRO DO CONJ PAULISTANO      3999
# 2  00000002      WM&R EMPREITEIRA DE CONSTRUCAO CIVIL LIMITADA      2240
#
#   qual_resp        capit_soc porte ente_fed
# 0        10  120000000000,00    05      NaN
# 1        16             0,00    05      NaN
# 2        49             0,00    05      NaN

# %%
empresas["cnpj"][2] = 	"26073984/0001-24"
# Out:
# C:\Users\User543\AppData\Local\Temp\ipykernel_13360\1767242304.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   empresas["cnpj"][2] = 	"26073984/0001-24"

# %%
empresas = empresas.drop(['nat_jurid', 'qual_resp', 'capit_soc', 'porte', 'ente_fed'], axis=1)

# %%
empresas
# Out:
#                cnpj                                       razao_social
# 0          00000000                                 BANCO DO BRASIL SA
# 1          00000001  ASSOCIACAO DE AMIGOS DE BAIRRO DO CONJ PAULISTANO
# 2  26073984/0001-24      WM&R EMPREITEIRA DE CONSTRUCAO CIVIL LIMITADA

# %%
resultado = pd.merge(
    empresas,
    condominios,
    on='cnpj',
    how='right'
)

# %%
resultado
# Out:
#                cnpj                                   razao_social  \
# 0  22157373/0001-03                                            NaN
# 1  08448393/0001-02                                            NaN
# 2  26073984/0001-24  WM&R EMPREITEIRA DE CONSTRUCAO CIVIL LIMITADA
# 3  26130593/0001-02                                            NaN
# 4  26186449/0001-80                                            NaN
#
#   matriz_filial                           nome_fantasia sit_cadast  \
# 0             1                                     NaN         02
# 1             1                                     NaN         02
# 2             1                            AR1 SOLUCOES         04
# 3             1  CONDOMINIO RESIDENCIAL MONTEIRO LOBATO         02
# 4             1     CONDOMINIO RESIDENCIAL CASTRO ALVES         02
#
#   data_sit_cadast motivo_sit_cadast nome_cidade_exterior pais data_inicio  \
# 0      04/09/2014                00                  NaN  NaN  04/09/2014
# ...
